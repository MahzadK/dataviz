# %%
# %matplotlib inline
import pandas as pd
import os
import os.path
import itertools
import matplotlib.pyplot as plt
import math
import pprint
import pprint as pp
import numpy as np

# %% [markdown]
# ## 1.  LOAD DATA

# %%
DATA_PATH = os.path.abspath(os.path.join(os.curdir, "data"))
DATA_PATH
GINI_FILE = "1-gini.csv"
os.path.join(DATA_PATH, GINI_FILE)
#/Users/khouiyadam/Documents/IGR204 Dataviz/dataviz/data
# Out:
# '/Users/khouiyadam/Documents/IGR204 Dataviz/dataviz/data/1-gini.csv'

# %%
DATA_PATH = os.path.abspath(os.path.join(os.curdir, "data"))
GINI_FILE = "1-gini.csv"
Year_in_school = "Years in school men 25-34.csv"
COUNTRIES_FILE = "3-countries.csv"

gini_df = pd.read_csv(os.path.join(DATA_PATH, GINI_FILE))
Year_in_school_df = pd.read_csv(os.path.join(DATA_PATH, Year_in_school), sep=";")
countries_df = pd.read_csv(os.path.join(DATA_PATH, COUNTRIES_FILE), sep=";", usecols = ['Country (en)', "Continent"])

# %%
gini_df
# Out:
#                  GINI index  1978  1979  1980   1981   1982  1983   1984  \
# 0               Afghanistan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 1                   Albania   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 2                   Algeria   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 3            American Samoa   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 4                   Andorra   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 5                    Angola   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 6       Antigua and Barbuda   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 7                 Argentina   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 8                   Armenia   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 9                     Aruba   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 10                Australia   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 11                  Austria   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 12               Azerbaijan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 13                  Bahamas   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 14                  Bahrain   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 15               Bangladesh   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 16                 Barbados   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 17                  Belarus   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 18                  Belgium   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 19                   Belize   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 20                    Benin   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 21                  Bermuda   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 22                   Bhutan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 23                  Bolivia   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 24   Bosnia and Herzegovina   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 25                 Botswana   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 26                   Brazil   NaN   NaN   NaN  57.48  58.15  58.4  58.43
# 27                   Brunei   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 28                 Bulgaria   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 29             Burkina Faso   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# ..                      ...   ...   ...   ...    ...    ...   ...    ...
# 197                  Sweden   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 198             Switzerland   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 199                   Syria   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 200              Tajikistan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 201                Tanzania   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 202                Thailand   NaN   NaN   NaN  45.22    NaN   NaN    NaN
# 203             Timor-Leste   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 204                    Togo   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 205                   Tonga   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 206     Trinidad and Tobago   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 207                 Tunisia   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 208                  Turkey   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 209            Turkmenistan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 210                  Uganda   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 211                 Ukraine   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 212    United Arab Emirates   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 213          United Kingdom   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 214           United States   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 215     Upper middle income   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 216                 Uruguay   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 217              Uzbekistan   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 218                 Vanuatu   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 219               Venezuela   NaN   NaN   NaN  55.82    NaN   NaN    NaN
# 220                 Vietnam   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 221   Virgin Islands (U.S.)   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 222      West Bank and Gaza   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 223                   World   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 224             Yemen, Rep.   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 225                  Zambia   NaN   NaN   NaN    NaN    NaN   NaN    NaN
# 226                Zimbabwe   NaN   NaN   NaN    NaN    NaN   NaN    NaN
#
#       1985   1986  ...     1998       1999     2000   2001   2002   2003  \
# 0      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 1      NaN    NaN  ...      NaN        NaN      NaN    NaN  28.15    NaN
# 2      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 3      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 4      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 5      NaN    NaN  ...      NaN        NaN  58.6400    NaN    NaN    NaN
# 6      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 7      NaN  44.51  ...    49.84        NaN      NaN    NaN  52.52    NaN
# 8      NaN    NaN  ...      NaN  36.010000      NaN    NaN  35.66  33.80
# 9      NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 10     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 11     NaN    NaN  ...      NaN        NaN  29.1480    NaN    NaN    NaN
# 12     NaN    NaN  ...      NaN        NaN      NaN  36.50    NaN    NaN
# 13     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 14     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 15     NaN    NaN  ...      NaN        NaN  30.7200    NaN    NaN    NaN
# 16     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 17     NaN    NaN  ...    30.28        NaN  30.3500    NaN  29.73    NaN
# 18     NaN    NaN  ...      NaN        NaN  32.9658    NaN    NaN    NaN
# 19     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 20     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN  38.62
# 21     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 22     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN  46.83
# 23     NaN    NaN  ...      NaN  57.790000      NaN    NaN  60.24    NaN
# 24     NaN    NaN  ...      NaN        NaN      NaN  28.03    NaN    NaN
# 25     NaN  54.21  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 26   58.96  58.13  ...    59.23  58.590000      NaN  58.69  58.23  57.61
# 27     NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 28     NaN    NaN  ...      NaN        NaN      NaN  34.34    NaN  29.24
# 29     NaN    NaN  ...    46.85        NaN      NaN    NaN    NaN  39.60
# ..     ...    ...  ...      ...        ...      ...    ...    ...    ...
# 197    NaN    NaN  ...      NaN        NaN  25.0000    NaN    NaN    NaN
# 198    NaN    NaN  ...      NaN        NaN  33.6820    NaN    NaN    NaN
# 199    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 200    NaN    NaN  ...      NaN  31.520000      NaN    NaN    NaN  32.62
# 201    NaN    NaN  ...      NaN        NaN  34.6200    NaN    NaN    NaN
# 202    NaN    NaN  ...      NaN  43.530000      NaN    NaN  41.96    NaN
# 203    NaN    NaN  ...      NaN        NaN      NaN  39.52    NaN    NaN
# 204    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 205    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 206    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 207  43.43    NaN  ...      NaN        NaN  40.8100    NaN    NaN    NaN
# 208    NaN    NaN  ...      NaN        NaN      NaN    NaN  42.71    NaN
# 209    NaN    NaN  ...    40.77        NaN      NaN    NaN    NaN    NaN
# 210    NaN    NaN  ...      NaN  43.070000      NaN    NaN  45.77    NaN
# 211    NaN    NaN  ...      NaN  28.960000      NaN    NaN  28.28    NaN
# 212    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 213    NaN    NaN  ...      NaN  35.973685      NaN    NaN    NaN    NaN
# 214    NaN    NaN  ...      NaN        NaN  40.8100    NaN    NaN    NaN
# 215    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 216    NaN    NaN  ...    45.18        NaN  44.5600  44.96    NaN    NaN
# 217    NaN    NaN  ...    45.35        NaN      NaN    NaN  34.55  36.72
# 218    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 219    NaN    NaN  ...    49.53        NaN      NaN    NaN    NaN  48.20
# 220    NaN    NaN  ...    35.52        NaN      NaN    NaN  37.55    NaN
# 221    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 222    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 223    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
# 224    NaN    NaN  ...    33.44        NaN      NaN    NaN    NaN    NaN
# 225    NaN    NaN  ...    53.44        NaN      NaN    NaN    NaN  42.08
# 226    NaN    NaN  ...      NaN        NaN      NaN    NaN    NaN    NaN
#
#       2004   2005   2006   2007
# 0      NaN    NaN    NaN    NaN
# 1      NaN  33.03    NaN    NaN
# 2      NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN
# 5      NaN    NaN    NaN    NaN
# 6      NaN    NaN    NaN    NaN
# 7      NaN  50.03    NaN    NaN
# 8      NaN    NaN    NaN    NaN
# 9      NaN    NaN    NaN    NaN
# 10     NaN    NaN    NaN    NaN
# 11     NaN    NaN    NaN    NaN
# 12     NaN    NaN    NaN    NaN
# 13     NaN    NaN    NaN    NaN
# 14     NaN    NaN    NaN    NaN
# 15     NaN  31.02    NaN    NaN
# 16     NaN    NaN    NaN    NaN
# 17     NaN  27.92    NaN    NaN
# 18     NaN    NaN    NaN    NaN
# 19     NaN    NaN    NaN    NaN
# 20     NaN    NaN    NaN    NaN
# 21     NaN    NaN    NaN    NaN
# 22     NaN    NaN    NaN    NaN
# 23     NaN  58.19    NaN    NaN
# 24   35.78    NaN    NaN    NaN
# 25     NaN    NaN    NaN    NaN
# 26     NaN  56.39    NaN  55.02
# 27     NaN    NaN    NaN    NaN
# 28     NaN    NaN    NaN    NaN
# 29     NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...
# 197    NaN    NaN    NaN    NaN
# 198    NaN    NaN    NaN    NaN
# 199    NaN    NaN    NaN    NaN
# 200  33.61    NaN    NaN    NaN
# 201    NaN    NaN    NaN    NaN
# 202  42.45    NaN    NaN    NaN
# 203    NaN    NaN    NaN    NaN
# 204    NaN    NaN  34.41    NaN
# 205    NaN    NaN    NaN    NaN
# 206    NaN    NaN    NaN    NaN
# 207    NaN    NaN    NaN    NaN
# 208    NaN  43.23    NaN    NaN
# 209    NaN    NaN    NaN    NaN
# 210    NaN  42.62    NaN    NaN
# 211    NaN  28.21    NaN    NaN
# 212    NaN    NaN    NaN    NaN
# 213    NaN    NaN    NaN    NaN
# 214    NaN    NaN    NaN    NaN
# 215    NaN    NaN    NaN    NaN
# 216    NaN  44.94  46.24    NaN
# 217    NaN    NaN    NaN    NaN
# 218    NaN    NaN    NaN    NaN
# 219    NaN  47.61  43.44    NaN
# 220  39.16    NaN  37.77    NaN
# 221    NaN    NaN    NaN    NaN
# 222    NaN    NaN    NaN    NaN
# 223    NaN    NaN    NaN    NaN
# 224    NaN  37.69    NaN    NaN
# 225  50.74    NaN    NaN    NaN
# 226    NaN    NaN    NaN    NaN
#
# [227 rows x 31 columns]

# %% [markdown]
# ## 2. PREPARE DATA

# %% [markdown]
# ### 2.1 Data selection

# %%
gini_df = gini_df.rename(columns={"GINI index": "country"})
Year_in_school_df = Year_in_school_df.rename(columns ={"Row Labels" :"country"})
countries_df = countries_df.rename(columns ={"Country (en)" :"country"})
Year_in_school_df.head(3)
# Out:
#        country 1970 1971 1972 1973 1974 1975 1976 1977 1978 ...   2000  2001  \
# 0  Afghanistan    1  1,1  1,1  1,2  1,3  1,3  1,4  1,4  1,5 ...    2,8   2,9
# 1      Albania  6,5  6,7  6,9    7  7,2  7,3  7,5  7,7  7,8 ...   10,4  10,4
# 2      Algeria  1,9    2  2,1  2,2  2,3  2,4  2,5  2,7  2,8 ...    6,3   6,5
#
#    2002  2003  2004  2005  2006  2007  2008 2009
# 0   2,9     3     3   3,1   3,1   3,2   3,3  3,3
# 1  10,5  10,6  10,7  10,7  10,8  10,9  10,9   11
# 2   6,6   6,7   6,8     7   7,1   7,2   7,3  7,3
#
# [3 rows x 41 columns]

# %% [markdown]
# ### 2.2 Load countries data

# %%
# vérification du nombre de pays dans chacune des dataframes

print ("Nombre de pays dans countries_df est {}".format (len(list (countries_df["country"].unique()))))
print ("Nombre de pays dans gini_df est {}".format (len(list (gini_df["country"].unique()))))
print ("Nombre de pays dans Year_in_school_df est {}".format (len(list (Year_in_school_df["country"].unique()))))
# Out:
# Nombre de pays dans countries_df est 248
# Nombre de pays dans gini_df est 227
# Nombre de pays dans Year_in_school_df est 175

# %%
# Récupère le continent auquel appartient chaque pays

gini_df_complet =pd.merge(gini_df, countries_df, on='country', how='outer')
gini_df_complet_cols = gini_df_complet.columns.tolist()
gini_df_complet_cols = gini_df_complet_cols[-1:] + gini_df_complet_cols[:-1]
gini_df_complet = gini_df_complet[gini_df_complet_cols]

Year_in_school_df_complet = pd.merge(Year_in_school_df, countries_df, on='country', how='outer')
Year_in_school_df_complet_cols = Year_in_school_df_complet.columns.tolist()

Year_in_school_df_complet_cols = Year_in_school_df_complet_cols[-1:] + Year_in_school_df_complet_cols[:-1]
Year_in_school_df_complet = Year_in_school_df_complet[Year_in_school_df_complet_cols]

Year_in_school_df_complet.head(3)
# Out:
#   Continent      country 1970 1971 1972 1973 1974 1975 1976 1977 ...   2000  \
# 0      Asia  Afghanistan    1  1,1  1,1  1,2  1,3  1,3  1,4  1,4 ...    2,8
# 1    Europe      Albania  6,5  6,7  6,9    7  7,2  7,3  7,5  7,7 ...   10,4
# 2    Africa      Algeria  1,9    2  2,1  2,2  2,3  2,4  2,5  2,7 ...    6,3
#
#    2001  2002  2003  2004  2005  2006  2007  2008 2009
# 0   2,9   2,9     3     3   3,1   3,1   3,2   3,3  3,3
# 1  10,4  10,5  10,6  10,7  10,7  10,8  10,9  10,9   11
# 2   6,5   6,6   6,7   6,8     7   7,1   7,2   7,3  7,3
#
# [3 rows x 42 columns]

# %%
#gini_df_complet.head(3)

# %%
gini_df_complet.transpose().head()
# Out:
#                    0        1        2               3        4       5    \
# Continent         Asia   Europe   Africa         Oceania   Europe  Africa
# country    Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola
# 1978               NaN      NaN      NaN             NaN      NaN     NaN
# 1979               NaN      NaN      NaN             NaN      NaN     NaN
# 1980               NaN      NaN      NaN             NaN      NaN     NaN
#
#                            6              7        8              9    \
# Continent        North America  South America     Asia  North America
# country    Antigua and Barbuda      Argentina  Armenia          Aruba
# 1978                       NaN            NaN      NaN            NaN
# 1979                       NaN            NaN      NaN            NaN
# 1980                       NaN            NaN      NaN            NaN
#
#                      ...                275      276             277  \
# Continent            ...               Asia  Oceania          Europe
# country              ...             Taiwan  Tokelau  Czech Republic
# 1978                 ...                NaN      NaN             NaN
# 1979                 ...                NaN      NaN             NaN
# 1980                 ...                NaN      NaN             NaN
#
#                                 278      279                      280  \
# Continent             North America  Oceania                   Europe
# country    Turks and Caicos Islands   Tuvalu  Holy See (Vatican City)
# 1978                            NaN      NaN                      NaN
# 1979                            NaN      NaN                      NaN
# 1980                            NaN      NaN                      NaN
#
#                          281               282             283  \
# Continent            Oceania         Australia          Africa
# country    Wallis and Futuna  Christmas Island  Western Sahara
# 1978                     NaN               NaN             NaN
# 1979                     NaN               NaN             NaN
# 1980                     NaN               NaN             NaN
#
#                                 284
# Continent                    Africa
# country    Central African Republic
# 1978                            NaN
# 1979                            NaN
# 1980                            NaN
#
# [5 rows x 285 columns]

# %%
# garder les méme colonnes 
print("Dimensions initiales ...")
print("   Taille gini colonnes : ", str(len(gini_df_complet.columns.values)))
print("   Taille year school colonnes : ", str(len(Year_in_school_df_complet.columns.values)))
print()

gini_not_in_year_school = [ colonne for colonne in gini_df_complet.columns.values if colonne not in Year_in_school_df_complet.columns.values ]

year_school_not_in_gini = [ colonne  for colonne in Year_in_school_df_complet.columns.values if colonne not in gini_df_complet.columns.values ]

print ("colonnes dans gini et pas dans mean year school {}".format(gini_not_in_year_school))
print ("colonnes dans mean year school et pas dans gini {}".format(year_school_not_in_gini))

print("Suppression des colonnes non communes ...")

gini_df_complet = gini_df_complet.drop(gini_not_in_year_school, axis = 1 )
Year_in_school_df_complet = Year_in_school_df_complet.drop(year_school_not_in_gini, axis = 1 )

print("\nDimensions finales")
print("    Taille gini colonnes : ", str(len(gini_df_complet.columns.values)))
print("    Taille year school colonnes : ", str(len(Year_in_school_df_complet.columns.values)))
# Out:
# Dimensions initiales ...
#    Taille gini colonnes :  32
#    Taille year school colonnes :  42
#
# colonnes dans gini et pas dans mean year school []
# colonnes dans mean year school et pas dans gini ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '2008', '2009']
# Suppression des colonnes non communes ...
#
# Dimensions finales
#     Taille gini colonnes :  32
#     Taille year school colonnes :  32

# %%
gini_df_complet = gini_df_complet.transpose()


gini_df_complet.drop(gini_df_complet.index[0],inplace =True)
gini_df_complet.columns = gini_df_complet.iloc[0]
gini_df_complet.drop(gini_df_complet.index[0], inplace=True)

gini_df_complet.head(3)
# Out:
# country Afghanistan Albania Algeria American Samoa Andorra Angola  \
# 1978            NaN     NaN     NaN            NaN     NaN    NaN
# 1979            NaN     NaN     NaN            NaN     NaN    NaN
# 1980            NaN     NaN     NaN            NaN     NaN    NaN
#
# country Antigua and Barbuda Argentina Armenia Aruba           ...             \
# 1978                    NaN       NaN     NaN   NaN           ...
# 1979                    NaN       NaN     NaN   NaN           ...
# 1980                    NaN       NaN     NaN   NaN           ...
#
# country Taiwan Tokelau Czech Republic Turks and Caicos Islands Tuvalu  \
# 1978       NaN     NaN            NaN                      NaN    NaN
# 1979       NaN     NaN            NaN                      NaN    NaN
# 1980       NaN     NaN            NaN                      NaN    NaN
#
# country Holy See (Vatican City) Wallis and Futuna Christmas Island  \
# 1978                        NaN               NaN              NaN
# 1979                        NaN               NaN              NaN
# 1980                        NaN               NaN              NaN
#
# country Western Sahara Central African Republic
# 1978               NaN                      NaN
# 1979               NaN                      NaN
# 1980               NaN                      NaN
#
# [3 rows x 285 columns]

# %%
gini_df_complet.shape
# Out:
# (30, 285)

# %%
Year_in_school_df_complet = Year_in_school_df_complet.transpose()

# %%
Year_in_school_df_complet.drop(Year_in_school_df_complet.index[0],inplace =True)
Year_in_school_df_complet.columns = Year_in_school_df_complet.iloc[0]
Year_in_school_df_complet.drop(Year_in_school_df_complet.index[0], inplace=True)
Year_in_school_df_complet.head()
# Out:
# country Afghanistan Albania Algeria Angola Antigua and Barbuda Argentina  \
# 1978            1,5     7,8     2,8    3,2                 9,5       8,1
# 1979            1,6       8     2,9    3,4                 9,6       8,2
# 1980            1,6     8,1     3,1    3,5                 9,8       8,4
# 1981            1,7     8,3     3,3    3,6                  10       8,5
# 1982            1,8     8,4     3,4    3,8                10,2       8,6
#
# country Armenia Australia Austria Azerbaijan           ...             \
# 1978          9      10,8    10,2        9,1           ...
# 1979        9,1      10,9    10,3        9,3           ...
# 1980        9,2        11    10,4        9,4           ...
# 1981        9,4        11    10,4        9,6           ...
# 1982        9,5      11,1    10,5        9,7           ...
#
# country Svalbard Tokelau Czech Republic Turks and Caicos Islands Tuvalu  \
# 1978         NaN     NaN            NaN                      NaN    NaN
# 1979         NaN     NaN            NaN                      NaN    NaN
# 1980         NaN     NaN            NaN                      NaN    NaN
# 1981         NaN     NaN            NaN                      NaN    NaN
# 1982         NaN     NaN            NaN                      NaN    NaN
#
# country Holy See (Vatican City) Wallis and Futuna Christmas Island  \
# 1978                        NaN               NaN              NaN
# 1979                        NaN               NaN              NaN
# 1980                        NaN               NaN              NaN
# 1981                        NaN               NaN              NaN
# 1982                        NaN               NaN              NaN
#
# country Western Sahara Central African Republic
# 1978               NaN                      NaN
# 1979               NaN                      NaN
# 1980               NaN                      NaN
# 1981               NaN                      NaN
# 1982               NaN                      NaN
#
# [5 rows x 260 columns]

# %%
print("Dimensions initiales ...")
print("   Taille gini colonnes : ", str(len(gini_df_complet.columns.values)))
print("   Taille year school colonnes : ", str(len(Year_in_school_df_complet.columns.values)))
print()

gini_not_in_year_school = [ colonne for colonne in gini_df_complet.columns.values if colonne not in Year_in_school_df_complet.columns.values ]

year_school_not_in_gini = [ colonne  for colonne in Year_in_school_df_complet.columns.values if colonne not in gini_df_complet.columns.values ]

print ("colonnes dans gini et pas dans mean year school {}".format(gini_not_in_year_school))
print ("colonnes dans mean year school et pas dans gini {}".format(year_school_not_in_gini))

print("Suppression des colonnes non communes ...")

gini_df_complet = gini_df_complet.drop(gini_not_in_year_school, axis = 1 )
Year_in_school_df_complet = Year_in_school_df_complet.drop(year_school_not_in_gini, axis = 1 )

print("\nDimensions finales")
print("    Taille gini colonnes : ", str(len(gini_df_complet.columns.values)))
print("    Taille year school colonnes : ", str(len(Year_in_school_df_complet.columns.values)))
# Out:
# Dimensions initiales ...
#    Taille gini colonnes :  285
#    Taille year school colonnes :  260
#
# colonnes dans gini et pas dans mean year school ['Channel Islands', 'East Asia & Pacific', 'Euro area', 'Europe & Central Asia', 'Faeroe Islands', 'Heavily indebted poor countries (HIPC)', 'High income', 'High income: nonOECD', 'High income: OECD', 'Hong Kong, China', 'Korea, Dem. Rep.', 'Latin America & Caribbean', 'Least developed countries: UN classification', 'Low & middle income', 'Low income', 'Lower middle income', 'Macao, China', 'Micronesia, Fed. Sts.', 'Middle East & North Africa', 'Middle income', 'South Asia', 'Sub-Saharan Africa', 'Upper middle income', 'Virgin Islands (U.S.)', 'World']
# colonnes dans mean year school et pas dans gini []
# Suppression des colonnes non communes ...
#
# Dimensions finales
#     Taille gini colonnes :  260
#     Taille year school colonnes :  260

# %%
gini_df_complet.head()
# Out:
# country Afghanistan Albania Algeria American Samoa Andorra Angola  \
# 1978            NaN     NaN     NaN            NaN     NaN    NaN
# 1979            NaN     NaN     NaN            NaN     NaN    NaN
# 1980            NaN     NaN     NaN            NaN     NaN    NaN
# 1981            NaN     NaN     NaN            NaN     NaN    NaN
# 1982            NaN     NaN     NaN            NaN     NaN    NaN
#
# country Antigua and Barbuda Argentina Armenia Aruba           ...             \
# 1978                    NaN       NaN     NaN   NaN           ...
# 1979                    NaN       NaN     NaN   NaN           ...
# 1980                    NaN       NaN     NaN   NaN           ...
# 1981                    NaN       NaN     NaN   NaN           ...
# 1982                    NaN       NaN     NaN   NaN           ...
#
# country Taiwan Tokelau Czech Republic Turks and Caicos Islands Tuvalu  \
# 1978       NaN     NaN            NaN                      NaN    NaN
# 1979       NaN     NaN            NaN                      NaN    NaN
# 1980       NaN     NaN            NaN                      NaN    NaN
# 1981       NaN     NaN            NaN                      NaN    NaN
# 1982       NaN     NaN            NaN                      NaN    NaN
#
# country Holy See (Vatican City) Wallis and Futuna Christmas Island  \
# 1978                        NaN               NaN              NaN
# 1979                        NaN               NaN              NaN
# 1980                        NaN               NaN              NaN
# 1981                        NaN               NaN              NaN
# 1982                        NaN               NaN              NaN
#
# country Western Sahara Central African Republic
# 1978               NaN                      NaN
# 1979               NaN                      NaN
# 1980               NaN                      NaN
# 1981               NaN                      NaN
# 1982               NaN                      NaN
#
# [5 rows x 260 columns]

# %%
gini_df_complet = gini_df_complet.stack()
gini_df_complet = gini_df_complet.to_frame().reset_index()
gini_df_complet = gini_df_complet.rename(columns= {0: 'gini' ,'level_0':'year'})
gini_df_complet.shape
# Out:
# (514, 3)

# %%
gini_df_complet.head()
# Out:
#    year     country   gini
# 0  1979      Panama  48.74
# 1  1980  Madagascar  46.85
# 2  1981      Brazil  57.48
# 3  1981  Costa Rica  47.49
# 4  1981    Thailand  45.22

# %%
Year_in_school_df_complet = Year_in_school_df_complet.stack()
Year_in_school_df_complet = Year_in_school_df_complet.to_frame().reset_index()
Year_in_school_df_complet = Year_in_school_df_complet.rename(columns= {0: 'mean' ,'level_0':'year'})
Year_in_school_df_complet.shape
# Out:
# (5250, 3)

# %%
def remove_comma(s):
    """
    Remplace les virgules d'une chaîne de caractères par des points.
    Utile pour les nombres décimaux écrits avec une virgule qui devront être castés de String vers Float
    """
    if not (type(s) is str or type(s) is np.str_):
        # just returns it untouched
        return s
    return s.replace(",", ".")

Year_in_school_df_complet.head()
# Out:
#    year              country mean
# 0  1978          Afghanistan  1,5
# 1  1978              Albania  7,8
# 2  1978              Algeria  2,8
# 3  1978               Angola  3,2
# 4  1978  Antigua and Barbuda  9,5

# %%
result = pd.merge(Year_in_school_df_complet, gini_df_complet,  how='inner', on=['year','country'])
result["mean"] =result["mean"].apply(remove_comma)
result["gini"] = result["gini"].apply(int)
result["mean"] = result["mean"].apply(float)
result.head()
# Out:
#    year     country  mean  gini
# 0  1979      Panama   7.6    48
# 1  1980  Madagascar   3.6    46
# 2  1981      Brazil   4.7    57
# 3  1981  Costa Rica   6.8    47
# 4  1981    Thailand   6.3    45

# %%
result_2 = pd.merge(result, countries_df,  how='left', on=['country'])

# %%
#result_2[result_2["Continent"].isnull()]
result_2[result_2["Continent"]=='Central America']
# Out:
#      year      country  mean  gini        Continent
# 0    1979       Panama   7.6    48  Central America
# 3    1981   Costa Rica   6.8    47  Central America
# 23   1986   Costa Rica   7.6    34  Central America
# 32   1987    Guatemala   4.3    58  Central America
# 68   1989  El Salvador   6.2    48  Central America
# 70   1989    Guatemala   4.5    59  Central America
# 80   1990   Costa Rica   8.2    45  Central America
# 81   1990     Honduras   5.4    57  Central America
# 94   1991       Panama   9.3    56  Central America
# 105  1992     Honduras   5.7    54  Central America
# 125  1993   Costa Rica   8.6    46  Central America
# 142  1993    Nicaragua   5.8    56  Central America
# 161  1994     Honduras   5.9    55  Central America
# 177  1995  El Salvador   7.0    49  Central America
# 184  1995       Panama   9.7    57  Central America
# 199  1996   Costa Rica   9.0    47  Central America
# 204  1996  El Salvador   7.2    52  Central America
# 214  1996       Panama   9.9    56  Central America
# 233  1997     Honduras   6.3    53  Central America
# 242  1997       Panama  10.0    48  Central America
# 251  1998   Costa Rica   9.3    48  Central America
# 255  1998  El Salvador   7.4    52  Central America
# 259  1998    Guatemala   5.5    55  Central America
# 271  1998    Nicaragua   6.3    53  Central America
# 289  1999     Honduras   6.5    51  Central America
# 315  2000   Costa Rica   9.5    46  Central America
# 318  2000  El Salvador   7.7    51  Central America
# 324  2000    Guatemala   5.7    54  Central America
# 332  2000       Panama  10.3    56  Central America
# 350  2001   Costa Rica   9.7    49  Central America
# 358  2001    Nicaragua   6.5    50  Central America
# 371  2002  El Salvador   8.0    52  Central America
# 374  2002    Guatemala   5.9    55  Central America
# 388  2002       Panama  10.6    56  Central America
# 411  2003   Costa Rica   9.9    49  Central America
# 414  2003  El Salvador   8.1    49  Central America
# 417  2003     Honduras   7.0    53  Central America
# 445  2004       Panama  10.8    54  Central America
# 459  2005   Costa Rica  10.1    47  Central America
# 464  2005  El Salvador   8.3    49  Central America
# 468  2005     Honduras   7.2    56  Central America
# 475  2005    Nicaragua   6.8    52  Central America
# 495  2006    Guatemala   6.3    53  Central America
# 496  2006     Honduras   7.4    55  Central America
# 500  2006       Panama  11.0    54  Central America

# %%
import seaborn as sns
def print_by_continent(continent):
    plt.figure(figsize=(10,8))
    plt.scatter( result_2[result_2["Continent"] == continent]["mean"].values , result_2[result_2["Continent"] == continent]["gini"].values, marker='o' )
    plt.xlabel("mean year school rate")
    plt.ylabel("Gini Index")
    plt.title("Gini index et mean year school rate ")
    plt.legend()
    plt.show()

# %%
print_by_continent("Central America")
# Out:
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
result_year = result_2[result_2["year"]=='2005']
result_year.head()
# Out:
#      year     country  mean  gini      Continent
# 451  2005     Albania  10.7    33         Europe
# 452  2005   Argentina  10.8    50  South America
# 453  2005  Bangladesh   5.5    31           Asia
# 454  2005     Belarus  12.5    27         Europe
# 455  2005     Bolivia   9.8    58  South America

# %%
## mettre la colonne Country comme index et générer un fichier JSON

# %%
#len (pd.unique(result_year.country))
result_year.index
#result_year.to_json(orient='index')
result_WT_year= result_year.drop('year', 1)
#result_WT_year
result_WT_year_reindex =result_WT_year.set_index('country')
#result_WT_year_reindex
json_country_index = result_WT_year_reindex.to_json(orient='index')
json_country_index
# Out:
# '{"Albania":{"mean":10.7,"gini":33,"Continent":"Europe"},"Argentina":{"mean":10.8,"gini":50,"Continent":"South America"},"Bangladesh":{"mean":5.5,"gini":31,"Continent":"Asia"},"Belarus":{"mean":12.5,"gini":27,"Continent":"Europe"},"Bolivia":{"mean":9.8,"gini":58,"Continent":"South America"},"Brazil":{"mean":7.8,"gini":56,"Continent":"South America"},"China":{"mean":9.0,"gini":41,"Continent":"Asia"},"Congo, Rep.":{"mean":9.5,"gini":47,"Continent":null},"Costa Rica":{"mean":10.1,"gini":47,"Continent":"Central America"},"Croatia":{"mean":11.1,"gini":28,"Continent":"Europe"},"Dominican Rep.":{"mean":8.8,"gini":49,"Continent":null},"Ecuador":{"mean":9.9,"gini":53,"Continent":"South America"},"Egypt":{"mean":9.7,"gini":32,"Continent":"Africa"},"El Salvador":{"mean":8.3,"gini":49,"Continent":"Central America"},"Ethiopia":{"mean":3.4,"gini":29,"Continent":"Africa"},"Gabon":{"mean":9.0,"gini":41,"Continent":"Africa"},"Georgia":{"mean":12.6,"gini":40,"Continent":"Asia"},"Honduras":{"mean":7.2,"gini":56,"Continent":"Central America"},"India":{"mean":7.7,"gini":36,"Continent":"Asia"},"Indonesia":{"mean":8.9,"gini":39,"Continent":"Asia"},"Iran":{"mean":9.2,"gini":38,"Continent":"Asia"},"Kenya":{"mean":9.2,"gini":47,"Continent":"Africa"},"Madagascar":{"mean":5.7,"gini":47,"Continent":"Africa"},"Mongolia":{"mean":9.3,"gini":33,"Continent":"Asia"},"Nicaragua":{"mean":6.8,"gini":52,"Continent":"Central America"},"Niger":{"mean":2.4,"gini":43,"Continent":"Africa"},"Pakistan":{"mean":6.9,"gini":31,"Continent":"Asia"},"Paraguay":{"mean":7.8,"gini":53,"Continent":"South America"},"Peru":{"mean":11.1,"gini":51,"Continent":"South America"},"Poland":{"mean":12.5,"gini":34,"Continent":"Europe"},"Romania":{"mean":12.9,"gini":31,"Continent":"Europe"},"Russia":{"mean":13.0,"gini":37,"Continent":"Europe"},"Senegal":{"mean":4.3,"gini":39,"Continent":"Africa"},"Turkey":{"mean":9.5,"gini":43,"Continent":"Asia"},"Uganda":{"mean":6.9,"gini":42,"Continent":"Africa"},"Ukraine":{"mean":12.8,"gini":28,"Continent":"Europe"},"Uruguay":{"mean":10.3,"gini":44,"Continent":"South America"},"Venezuela":{"mean":9.3,"gini":47,"Continent":"South America"},"Yemen, Rep.":{"mean":6.3,"gini":37,"Continent":null}}'

# %% [markdown]
# ## mettre la colonne continent comme index et générer un fichier JSON

# %%
result_WT_year_reindex_2 =result_WT_year.set_index('Continent')
result_WT_year_reindex_2.head()
# Out:
#                   country  mean  gini
# Continent
# Europe            Albania  10.7    33
# South America   Argentina  10.8    50
# Asia           Bangladesh   5.5    31
# Europe            Belarus  12.5    27
# South America     Bolivia   9.8    58

# %%
result_Mlti_index = result_WT_year.set_index(['Continent', 'country'], inplace=False).groupby(level=['Continent','country'])
print (result_Mlti_index.head())
# Out:
#                                 mean  gini
# Continent       country
# Europe          Albania         10.7    33
# South America   Argentina       10.8    50
# Asia            Bangladesh       5.5    31
# Europe          Belarus         12.5    27
# South America   Bolivia          9.8    58
#                 Brazil           7.8    56
# Asia            China            9.0    41
# NaN             Congo, Rep.      9.5    47
# Central America Costa Rica      10.1    47
# Europe          Croatia         11.1    28
# NaN             Dominican Rep.   8.8    49
# South America   Ecuador          9.9    53
# Africa          Egypt            9.7    32
# Central America El Salvador      8.3    49
# Africa          Ethiopia         3.4    29
#                 Gabon            9.0    41
# Asia            Georgia         12.6    40
# Central America Honduras         7.2    56
# Asia            India            7.7    36
#                 Indonesia        8.9    39
#                 Iran             9.2    38
# Africa          Kenya            9.2    47
#                 Madagascar       5.7    47
# Asia            Mongolia         9.3    33
# Central America Nicaragua        6.8    52
# Africa          Niger            2.4    43
# Asia            Pakistan         6.9    31
# South America   Paraguay         7.8    53
#                 Peru            11.1    51
# Europe          Poland          12.5    34
#                 Romania         12.9    31
#                 Russia          13.0    37
# Africa          Senegal          4.3    39
# Asia            Turkey           9.5    43
# Africa          Uganda           6.9    42
# Europe          Ukraine         12.8    28
# South America   Uruguay         10.3    44
#                 Venezuela        9.3    47
# NaN             Yemen, Rep.      6.3    37

# %%
#result_WT_year
result_Mlti_index = result_WT_year.set_index(['Continent', 'country'], inplace=False).groupby(level=['Continent','country']).sum()
#print (result_Mlti_index)


json_continent_index = result_Mlti_index.to_json(orient='index')

json_continent_index
# Out:
# '{"["Africa","Egypt"]":{"mean":9.7,"gini":32},"["Africa","Ethiopia"]":{"mean":3.4,"gini":29},"["Africa","Gabon"]":{"mean":9.0,"gini":41},"["Africa","Kenya"]":{"mean":9.2,"gini":47},"["Africa","Madagascar"]":{"mean":5.7,"gini":47},"["Africa","Niger"]":{"mean":2.4,"gini":43},"["Africa","Senegal"]":{"mean":4.3,"gini":39},"["Africa","Uganda"]":{"mean":6.9,"gini":42},"["Asia","Bangladesh"]":{"mean":5.5,"gini":31},"["Asia","China"]":{"mean":9.0,"gini":41},"["Asia","Georgia"]":{"mean":12.6,"gini":40},"["Asia","India"]":{"mean":7.7,"gini":36},"["Asia","Indonesia"]":{"mean":8.9,"gini":39},"["Asia","Iran"]":{"mean":9.2,"gini":38},"["Asia","Mongolia"]":{"mean":9.3,"gini":33},"["Asia","Pakistan"]":{"mean":6.9,"gini":31},"["Asia","Turkey"]":{"mean":9.5,"gini":43},"["Central America","Costa Rica"]":{"mean":10.1,"gini":47},"["Central America","El Salvador"]":{"mean":8.3,"gini":49},"["Central America","Honduras"]":{"mean":7.2,"gini":56},"["Central America","Nicaragua"]":{"mean":6.8,"gini":52},"["Europe","Albania"]":{"mean":10.7,"gini":33},"["Europe","Belarus"]":{"mean":12.5,"gini":27},"["Europe","Croatia"]":{"mean":11.1,"gini":28},"["Europe","Poland"]":{"mean":12.5,"gini":34},"["Europe","Romania"]":{"mean":12.9,"gini":31},"["Europe","Russia"]":{"mean":13.0,"gini":37},"["Europe","Ukraine"]":{"mean":12.8,"gini":28},"["South America","Argentina"]":{"mean":10.8,"gini":50},"["South America","Bolivia"]":{"mean":9.8,"gini":58},"["South America","Brazil"]":{"mean":7.8,"gini":56},"["South America","Ecuador"]":{"mean":9.9,"gini":53},"["South America","Paraguay"]":{"mean":7.8,"gini":53},"["South America","Peru"]":{"mean":11.1,"gini":51},"["South America","Uruguay"]":{"mean":10.3,"gini":44},"["South America","Venezuela"]":{"mean":9.3,"gini":47}}'

# %%
def recur_dictify(frame):
    if len(frame.columns) == 1:
        if frame.values.size == 1: return frame.values[0][0]
        return frame.values.squeeze()
    grouped = frame.groupby(frame.columns[0])
    d = {k: recur_dictify(g.ix[:,1:]) for k,g in grouped}
    return d

# %%
result_WT_year_reindex_2.head(2)
# Out:
#                  country  mean  gini
# Continent
# Europe           Albania  10.7    33
# South America  Argentina  10.8    50

# %%
#print (result_WT_year_reindex_2.groupby(result_WT_year_reindex_2.index))


grouped_df = result_WT_year_reindex_2.groupby(result_WT_year_reindex_2.index)

#for key, item in grouped_df:
    #print (key, "\n\n")




#json_continent_index = grouped_df.apply(lambda x: x.to_json(orient='index'))
#json_continent_index
grouped_df.head(3)
# Out:
#                         country  mean  gini
# Continent
# Europe                  Albania  10.7    33
# South America         Argentina  10.8    50
# Asia                 Bangladesh   5.5    31
# Europe                  Belarus  12.5    27
# South America           Bolivia   9.8    58
# South America            Brazil   7.8    56
# Asia                      China   9.0    41
# NaN                 Congo, Rep.   9.5    47
# Central America      Costa Rica  10.1    47
# Europe                  Croatia  11.1    28
# NaN              Dominican Rep.   8.8    49
# Africa                    Egypt   9.7    32
# Central America     El Salvador   8.3    49
# Africa                 Ethiopia   3.4    29
# Africa                    Gabon   9.0    41
# Asia                    Georgia  12.6    40
# Central America        Honduras   7.2    56
# NaN                 Yemen, Rep.   6.3    37

# %%
def retro_dictify(frame):
    d = {}
    for row in frame.values:
        here = d
        for elem in row[:-2]:
            if elem not in here:
               
                here[elem] = {}
            here = here[elem]
        
        
        for i ,k in  enumerate (list (frame.columns[1:])):
            #here[row[-2]] = row[-1]
            #print("k",k)
            #print("i",i)
            #here[row[-2]] = row[-1]
             here [k] = row[i-2]
            #print ("row[-2]",row[-2])
            #print ("row[-1]",row[-1])
            #print ("row",row)
        #print (here)
    return d

# %%
dictionnary = grouped_df.apply(retro_dictify)

data_viz =dictionnary.to_json()

# %%
with open('data_viz.json', 'w') as f:
    json.dump(data_viz, f, ensure_ascii=False)

# %% [markdown]
# ## plot

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(10, 24))
sns.set_color_codes("pastel")
sns.barplot(x="gini", y="country", data=result_year,label="Gini", color="b")

sns.set_color_codes("muted")
sns.barplot(x="mean", y="country", data=result_year,label="Mean year school", color="b")


ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, max(result["gini"])), ylabel="",xlabel="Gini vs Mean year school")
sns.despine(left=True, bottom=True)

# %%
def ratio_gini_education (key ,value):
    df_filtred = result_2[result_2[key]== value]
    sns.set(style="whitegrid")
    f, ax = plt.subplots(figsize=(10, 24))
    sns.set_color_codes("pastel")
    sns.barplot(x="gini", y="country", data=df_filtred,label="Gini", color="b")

    sns.set_color_codes("muted")
    sns.barplot(x="mean", y="country", data=df_filtred,label="Mean year school", color="b")


    ax.legend(ncol=2, loc="lower right", frameon=True)
    ax.set(xlim=(0, max(df_filtred["gini"])), ylabel="",xlabel="Gini vs Mean year school")
    sns.despine(left=True, bottom=True)

# %%
ratio_gini_education ("year" ,"2005")
