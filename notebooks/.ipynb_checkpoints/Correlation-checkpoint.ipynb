# %%
import pandas as pd
import numpy as np

# %%
path = '../data/gini-complete.csv'
df =  pd.read_csv(path)

# %%
path = '../data/immigre.csv'
df2 =  pd.read_csv(path, sep =';')
df2.head()
# Out:
#         countries  Employment_rate-Foreign-born  Employment_rate-Native-born  \
# 0       Australia                          69.9                         73.5
# 1         Austria                          64.7                         72.8
# 2         Belgium                          53.3                         63.6
# 3          Canada                          71.0                         73.0
# 4  Czech_Republic                          71.1                         70.2
#
#    Unemployment rate-Foreign-born  Unemployment rate-Native-born  \
# 0                             6.2                            6.2
# 1                            10.7                            4.6
# 2                            17.0                            6.8
# 3                             7.4                            6.9
# 4                             6.8                            5.1
#
#    Participation rate-Foreign-born  Participation rate-Native-born
# 0                             74.6                            78.3
# 1                             72.4                            76.3
# 2                             64.2                            68.3
# 3                             76.7                            78.4
# 4                             76.3                            73.9

# %%
df3 = pd.merge(df, df2, on='countries', how='inner')
df3.head()
# Out:
#        countries  Gini  Employment_rate-Foreign-born  \
# 0         Mexico  48.3                          51.8
# 1  United_States  45.0                          69.2
# 2         Israel  42.8                          78.0
# 3         Turkey  40.2                          44.4
# 4         Greece  36.7                          52.2
#
#    Employment_rate-Native-born  Unemployment rate-Foreign-born  \
# 0                         60.8                             5.4
# 1                         67.2                             5.0
# 2                         65.9                             4.3
# 3                         50.3                            12.8
# 4                         50.6                            32.0
#
#    Unemployment rate-Native-born  Participation rate-Foreign-born  \
# 0                            4.5                             54.7
# 1                            5.6                             72.9
# 2                            5.5                             81.4
# 3                           10.4                             50.9
# 4                           24.4                             76.9
#
#    Participation rate-Native-born
# 0                            63.7
# 1                            71.1
# 2                            69.7
# 3                            56.1
# 4                            66.9

# %%
df_corr = df3.corr()

# %%
df_corr
# Out:
#                                      Gini  Employment_rate-Foreign-born  \
# Gini                             1.000000                     -0.154423
# Employment_rate-Foreign-born    -0.154423                      1.000000
# Employment_rate-Native-born     -0.478796                      0.719585
# Unemployment rate-Foreign-born  -0.105497                     -0.633271
# Unemployment rate-Native-born    0.209514                     -0.545524
# Participation rate-Foreign-born -0.258956                      0.805685
# Participation rate-Native-born  -0.505791                      0.644740
#
#                                  Employment_rate-Native-born  \
# Gini                                               -0.478796
# Employment_rate-Foreign-born                        0.719585
# Employment_rate-Native-born                         1.000000
# Unemployment rate-Foreign-born                     -0.494467
# Unemployment rate-Native-born                      -0.687779
# Participation rate-Foreign-born                     0.546342
# Participation rate-Native-born                      0.931250
#
#                                  Unemployment rate-Foreign-born  \
# Gini                                                  -0.105497
# Employment_rate-Foreign-born                          -0.633271
# Employment_rate-Native-born                           -0.494467
# Unemployment rate-Foreign-born                         1.000000
# Unemployment rate-Native-born                          0.874089
# Participation rate-Foreign-born                       -0.053662
# Participation rate-Native-born                        -0.193196
#
#                                  Unemployment rate-Native-born  \
# Gini                                                  0.209514
# Employment_rate-Foreign-born                         -0.545524
# Employment_rate-Native-born                          -0.687779
# Unemployment rate-Foreign-born                        0.874089
# Unemployment rate-Native-born                         1.000000
# Participation rate-Foreign-born                      -0.028324
# Participation rate-Native-born                       -0.377265
#
#                                  Participation rate-Foreign-born  \
# Gini                                                   -0.258956
# Employment_rate-Foreign-born                            0.805685
# Employment_rate-Native-born                             0.546342
# Unemployment rate-Foreign-born                         -0.053662
# Unemployment rate-Native-born                          -0.028324
# Participation rate-Foreign-born                         1.000000
# Participation rate-Native-born                          0.683265
#
#                                  Participation rate-Native-born
# Gini                                                  -0.505791
# Employment_rate-Foreign-born                           0.644740
# Employment_rate-Native-born                            0.931250
# Unemployment rate-Foreign-born                        -0.193196
# Unemployment rate-Native-born                         -0.377265
# Participation rate-Foreign-born                        0.683265
# Participation rate-Native-born                         1.000000

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Gini Correlation')
    labels=['Gini','Employment_rate-Foreign-born', 'Employment_rate-Native-born', 'Unemployment rate-Foreign-born',
           'Unemployment rate-Native-born', 'Participation rate-Foreign-born','Participation rate-Native-born']
    ax1.set_xticklabels(labels,fontsize=12, rotation=90)
    ax1.set_yticklabels(labels,fontsize=12)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[-0.1, -0.3, -0.5, -0.76, -0.8, -0.9, 0.0, .1,.3,.5,.7,.9,1])
    plt.show()

# %%
correlation_matrix(df3)

# %%
import seaborn as sns
# %matplotlib inline
# calculate the correlation matrix
corr = df3.corr()

# plot the heatmap
sns.heatmap(corr)

# %%
import seaborn as sns
sns.set()

sns.pairplot(df3, hue="Gini")

# %%
path = '../data/injurieRoad2006.csv'
df_injur =  pd.read_csv(path, sep=';')
df_injur.head()
# Out:
#         countries  injuries
# 0       Australia    1571.0
# 1         Austria    6280.9
# 2         Belgium    6188.2
# 3          Canada    6139.0
# 4  Czech Republic    2738.0

# %%
df4 = pd.merge(df, df_injur, on='countries', how='inner')
df4.head()
# Out:
#   countries  Gini  injuries
# 0     Chile  52.1    2861.7
# 1    Mexico  48.3    1682.6
# 2    Israel  42.8    5032.0
# 3    Russia  42.0    2003.0
# 4    Turkey  40.2    2317.0

# %%
import seaborn as sns
sns.set()

sns.pairplot(df4, hue="Gini")

# %%
path = '../data/cancer2012.csv'
df_cancer =  pd.read_csv(path, sep=';')

# %%
df_cancer2 = df_cancer.groupby(df_cancer['countries']).sum()

df_cancer2.head()
df_cancer3 = df_cancer2.copy()
df_cancer3['countries'] = df_cancer2.index

# %%
df5 = pd.merge(df, df_cancer3, on='countries', how='inner')
df5.head()
# Out:
#   countries  Gini  cancer
# 0  Colombia  53.5   184.5
# 1     Chile  52.1   204.0
# 2    Brazil  51.9   237.6
# 3    Mexico  48.3   146.8
# 4    Israel  42.8   340.3

# %%
import seaborn as sns
sns.set()

sns.pairplot(df5, hue="Gini")

# %% [markdown]
# # CHILDREN

# %%
def drawMatrixScatter(path, df):
    df_infant_mortality =  pd.read_csv(path, sep=';')
    df_corr = pd.merge(df, df_infant_mortality, on='countries', how='inner')
    df_corr.head()
    sns.set()
    sns.pairplot(df_corr, hue="Gini")

# %%
path = '../data/children/average_disposable_income.csv'
drawMatrixScatter(path, df)

# %% [markdown]
# Average equivalised household disposable income in households with children (0-17-year-olds), USD PPP thousands, circa 2005.
#
# Income data is average family income for children aged 0-17 years. Data is for various years between 2003 and 2005. It is drawn from national household panel surveys of all OECD countries. Data is converted to common USD using OECD purchasing power parity exchange rates, and equivalised using the square root of the family size.

# %%
path = '../data/children/average_mean_literacy_score.csv'
drawMatrixScatter(path, df)

# %% [markdown]
# Children in poor households (50% of median income), 2005.
#
# The child poverty measure used is the proportion of households with children living on an equivalised income below 50% of the national median income for the year 2005. Children are defined as those aged 0-17 years. All OECD countries are included.

# %%
path = '../data/children/breastfeeding_rates.csv'
drawMatrixScatter(path, df)
