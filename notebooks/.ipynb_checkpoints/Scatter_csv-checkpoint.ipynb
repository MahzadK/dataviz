# %%
# %matplotlib inline
import pandas as pd
import os
import os.path
import itertools
import matplotlib.pyplot as plt
import math
import pprint
import pprint as pp
import numpy as np

# %% [markdown]
# ## 1.  LOAD DATA

# %%
DATA_PATH = os.path.abspath(os.path.join(os.pardir, "data/gapminder/fichiers_csv"))
DATA_PATH2 = os.path.abspath(os.path.join(os.pardir, "data"))
Child_death_FILE = "teen-fertility.csv"
GINI_FILE = "gini-complete.csv"
#Year_in_school = "Years in school men 25-34.csv""
#FERTILITY_FILE = "teen-fertility.csv"
COUNTRIES_FILE = "3-countries.csv"
#fertility_df = pd.read_csv(os.path.join(DATA_PATH, FERTILITY_FILE), sep=";")
gini_df = pd.read_csv(os.path.join(DATA_PATH, GINI_FILE),sep=",")

child_death_df = pd.read_csv(os.path.join(DATA_PATH, Child_death_FILE), sep=";",encoding = 'ISO-8859-1')
countries_df = pd.read_csv(os.path.join(DATA_PATH2, COUNTRIES_FILE), sep=";", usecols = ['Country (en)', "Continent"])
countries_df = countries_df.rename(columns ={"Country (en)" :"countries"})
path_scatter = os.path.join(os.pardir, "scatter")

# %%
df_intermediate = pd.merge(gini_df, child_death_df,  how='inner', on=['countries'])

# %%
df_intermediate.dropna(axis=0,inplace=True)

# %%
df_final = pd.merge(df_intermediate, countries_df,  how='left', on=['countries'])

# %%
df_final
# Out:
#        countries  Gini  Teen-fertility        Continent
# 0        Lesotho  63.2          71.000           Africa
# 1          Haiti  60.8          45.000    North America
# 2       Botswana  60.5          50.000           Africa
# 3        Namibia  59.7          70.000           Africa
# 4       Honduras  57.7          92.000  Central America
# 5         Zambia  57.5         145.000           Africa
# 6       Colombia  53.5          73.000    South America
# 7       Paraguay  53.2          71.000    South America
# 8      Guatemala  53.0         106.000  Central America
# 9          Chile  52.1          58.000    South America
# 10        Panama  51.9          81.000  Central America
# 11        Brazil  51.9          76.000    South America
# 12     Swaziland  50.4          81.000           Africa
# 13        Gambia  50.2          75.000           Africa
# 14      Zimbabwe  50.1          62.000           Africa
# 15       Ecuador  48.5          82.000    South America
# 16      Thailand  48.4          42.000             Asia
# 17        Mexico  48.3          70.000    North America
# 18    Madagascar  47.5         132.000           Africa
# 19         China  46.9           9.000             Asia
# 20        Rwanda  46.8          38.000           Africa
# 21       Bolivia  46.6          78.000    South America
# 22     Singapore  46.4           5.000             Asia
# 23      Malaysia  46.2          13.000             Asia
# 24   Philippines  46.0          53.000             Asia
# 25       Georgia  46.0          44.000             Asia
# 26     Argentina  45.8          67.400    South America
# 27    Mozambique  45.6         144.000           Africa
# 28       Jamaica  45.5          76.000    North America
# 29       Uruguay  45.3          61.000    South America
# ..           ...   ...             ...              ...
# 89       Croatia  32.0          13.000           Europe
# 90         Italy  31.9           7.000           Europe
# 91   Timor-Leste  31.9          63.000             Asia
# 92       Ireland  31.3          18.000           Europe
# 93         Egypt  30.8          45.000           Africa
# 94       Hungary  30.6          20.000           Europe
# 95    Luxembourg  30.4           9.000           Europe
# 96       Armenia  30.3          27.200             Asia
# 97     Australia  30.3          16.800        Australia
# 98        France  30.1           7.000           Europe
# 99      Pakistan  29.6          31.000             Asia
# 100      Austria  29.2          11.202           Europe
# 101      Albania  29.0          11.200           Europe
# 102   Kazakhstan  28.9          29.000             Asia
# 103  Switzerland  28.7           4.000           Europe
# 104      Moldova  28.5          33.000           Europe
# 105      Iceland  28.0          15.000           Europe
# 106        Malta  27.7          19.000           Europe
# 107      Romania  27.3          39.000           Europe
# 108      Germany  27.0          10.000           Europe
# 109       Norway  26.8           9.300           Europe
# 110      Finland  26.8           8.700           Europe
# 111      Belarus  26.5          20.794           Europe
# 112   Montenegro  26.2          17.000           Europe
# 113      Belgium  25.9          10.000           Europe
# 114  Netherlands  25.1           5.000           Europe
# 115       Sweden  24.9           6.000           Europe
# 116      Denmark  24.8           6.200           Europe
# 117      Ukraine  24.6          32.000           Europe
# 118     Slovenia  23.7           5.000           Europe
#
# [119 rows x 4 columns]

# %%
#df_final.to_csv(path_scatter+"teen-fertility", sep=',', encoding='utf-8')
df_final.to_csv(path_scatter+'/teen-fertility.csv',sep=',', encoding='utf-8')

# %%
path_scatter
# Out:
# '../scatter'

# %%
DATA_PATH
# Out:
# '/Users/khouiyadam/Documents/IGR204 Dataviz/dataviz/data/gapminder/fichiers_csv'

# %%
def genrate_csv(filename):
    print (filename)
    child_death_df = pd.read_csv(os.path.join(DATA_PATH, filename), sep=";",encoding = 'ISO-8859-1')
    df_intermediate = pd.merge(gini_df, child_death_df,  how='inner', on=['countries'])
    df_intermediate.dropna(axis=0,inplace=True)
    df_final = pd.merge(df_intermediate, countries_df,  how='left', on=['countries'])
    df_final.rename(columns = {df_final.columns.tolist()[2]:'value'}, inplace=True)
    print (df_final.head(3))
    df_final.to_csv(path_scatter+'/'+filename,sep=',', encoding='utf-8')

# %%
path_scatter
# Out:
# '../scatter'

# %% [raw]
# genrate_csv("Child out of school primary.csv")

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(DATA_PATH) if isfile(join(DATA_PATH, f))]

# %%
DATA_PATH
# Out:
# '/Users/khouiyadam/Documents/IGR204 Dataviz/dataviz/data/gapminder/fichiers_csv'

# %%
# %%time
for file_name in onlyfiles :
    _, fileExtension = os.path.splitext(file_name)
    if fileExtension ==".csv":
        genrate_csv(file_name)
# Out:
# .DS_Store
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'countries'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-5e9df015d1a7> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'for file_name in onlyfiles :\n    \n    genrate_csv(file_name)')
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-18-53c936ae10e7> in genrate_csv(filename)
#       2     print (filename)
#       3     child_death_df = pd.read_csv(os.path.join(DATA_PATH, filename), sep=";",encoding = 'ISO-8859-1')
# ----> 4     df_intermediate = pd.merge(gini_df, child_death_df,  how='inner', on=['countries'])
#       5     df_intermediate.dropna(axis=0,inplace=True)
#       6     df_final = pd.merge(df_intermediate, countries_df,  how='left', on=['countries'])
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      59                          right_on=right_on, left_index=left_index,
#      60                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 61                          copy=copy, indicator=indicator)
#      62     return op.get_result()
#      63 if __debug__:
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/tools/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     541         (self.left_join_keys,
#     542          self.right_join_keys,
# --> 543          self.join_names) = self._get_merge_keys()
#     544
#     545     def get_result(self):
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/tools/merge.py in _get_merge_keys(self)
#     808                     if not is_rkey(rk):
#     809                         if rk is not None:
# --> 810                             right_keys.append(right[rk]._values)
#     811                         else:
#     812                             # work-around for merge_asof(right_index=True)
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/khouiyadam/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'countries'
